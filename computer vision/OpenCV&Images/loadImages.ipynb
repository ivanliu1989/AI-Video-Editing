# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("../mmexport1545548449041.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread("../asdqweqew.jpg")

# %%
type(img) # Important!!!!!!!
# Out:
# NoneType

# %%
img.shape
# Out:
# (1124, 1080, 3)

# %%
plt.imshow(img)

# %%
# Matplotlib --> RGB
# OpenCV --> BGR

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("../mmexport1545548449041.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
img_gray.shape
# Out:
# (1124, 1080)

# %%
new_img = cv2.resize(fix_img, (1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.2
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (225, 216, 3)

# %%
new_img = cv2.flip(fix_img,-1)
plt.imshow(new_img)

# %%
cv2.imwrite("../totally_new.jpg", new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
