# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
dark_ivan = cv2.imread("../mmexport1545548449041.jpg")
show_ivan = cv2.cvtColor(dark_ivan, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(show_ivan)

# %%
hist_values = cv2.calcHist([dark_ivan], channels=[0], mask=None, histSize=[256],ranges=[0,256]) # For Blue

# %%
plt.plot(hist_values)

# %%
hist_values = cv2.calcHist([dark_ivan], channels=[1], mask=None, histSize=[256],ranges=[0,256]) # For Green

# %%
plt.plot(hist_values)

# %%
img = dark_ivan

# %%
color = ('b', 'g', 'r')

for i, color in enumerate(color):
    histr = cv2.calcHist([img],[i],None, histSize=[256],ranges=[0,256])
    plt.plot(histr, color=color)
    plt.xlim([0,256])

# %%
img_hist_equal = dark_ivan

# %%
mask = np.zeros(dark_ivan.shape[:2], np.uint8)

# %%
# plt.imshow(mask, cmap='gray')
mask[200:800, 100:900] = 255
# plt.imshow(mask, cmap='gray')

# %%
mased_img = cv2.bitwise_and(img_hist_equal,img_hist_equal,mask=mask)

# %%
show_masked_img = cv2.bitwise_and(show_ivan, show_ivan, mask=mask)

# %%
plt.imshow(show_masked_img)

# %%
hist_mask_values_red = cv2.calcHist([dark_ivan], [2], mask=mask, histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_mask_values_red)

# %%
hist_mask_values_red = cv2.calcHist([dark_ivan], [2], mask=None, histSize=[256],ranges=[0,256])
plt.plot(hist_mask_values_red)

# %%
gorilla = cv2.imread("../mmexport1545548449041.jpg", 0)

# %%
def display_img(img):
    fig = plt.figure(figsize = (12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap='gray')

# %%
display_img(gorilla)

# %%
hist_values = cv2.calcHist([gorilla], [0], mask=None, histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
eq_gorilla = cv2.equalizeHist(gorilla)

# %%
display_img(eq_gorilla)

# %%
hist_values = cv2.calcHist([eq_gorilla], [0], mask=None, histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
def display_img(img):
    fig = plt.figure(figsize = (12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)
    
dark_ivan = cv2.imread("../mmexport1545548449041.jpg")
show_ivan = cv2.cvtColor(dark_ivan, cv2.COLOR_BGR2RGB)

# %%
display_img(show_ivan)

# %%
eq_show_ivan = cv2.equalizeHist(show_ivan)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-50-1ddab3e97300> in <module>()
# ----> 1 eq_show_ivan = cv2.equalizeHist(show_ivan)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\histogram.cpp:3334: error: (-215:Assertion failed) _src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function 'cv::equalizeHist'
