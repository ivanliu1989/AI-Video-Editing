# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread("../mmexport1545548449041.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread("../502012120_univ_sqr_xl.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1_resize = cv2.resize(img1, (600,600))
img2_resize = cv2.resize(img2, (600,600))

# %%
blended = cv2.addWeighted(src1 = img1_resize, alpha = 0.8, src2 = img2_resize, beta = 0.3, gamma=0) # only works images with same sizes

# %%
plt.imshow(blended)

# %%
# Overlay small image on top of a larger image (on Blending)
# numpy reassignment
img1 = cv2.imread("../mmexport1545548449041.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread("../502012120_univ_sqr_xl.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
large_img[y_offset:y_end, x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %%
# Blend together images of different sizes
img1 = cv2.imread("../mmexport1545548449041.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread("../502012120_univ_sqr_xl.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
img1.shape
# Out:
# (1124, 1080, 3)

# %%
x_offset = img1.shape[1] - img2.shape[1]
y_offset = img1.shape[0] - img2.shape[0]

# %%
rows, cols, channels = img2.shape

# %%
roi = img1[y_offset:img1.shape[0], x_offset:img1.shape[1]]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray, cmap = "gray")

# %%
mask_inv = cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv, cmap = "gray")

# %%
mask_inv.shape
# Out:
# (600, 600)

# %%
import numpy as np
white_background = np.full(img2.shape, 255, dtype = np.uint8)

# %%
white_background.shape
# Out:
# (600, 600, 3)

# %%
bk = cv2.bitwise_or(white_background, white_background, mask = mask_inv)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2, img2, mask=mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi = cv2.bitwise_or(roi, fg)

# %%
plt.imshow(final_roi)

# %%
large_img = img1
small_img = final_roi
