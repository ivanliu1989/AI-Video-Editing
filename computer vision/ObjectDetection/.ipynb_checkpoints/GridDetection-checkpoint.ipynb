# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
full = cv2.imread('../mmexport1545548449041.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %%
found, corners = cv2.findChessboardCorners(full, (7,7))

# %%
cv2.drawChessboardCorners(full, (7,7), corners, found)
# Out:
# array([[[ 45,  37,  18],
#         [ 45,  37,  18],
#         [ 45,  37,  18],
#         ...,
#         [ 83,  57,  34],
#         [ 83,  57,  34],
#         [ 83,  57,  34]],
#
#        [[ 46,  38,  19],
#         [ 46,  38,  19],
#         [ 46,  38,  19],
#         ...,
#         [ 84,  58,  35],
#         [ 84,  58,  35],
#         [ 84,  58,  35]],
#
#        [[ 48,  40,  21],
#         [ 48,  40,  21],
#         [ 48,  40,  21],
#         ...,
#         [ 85,  59,  36],
#         [ 85,  59,  36],
#         [ 85,  59,  36]],
#
#        ...,
#
#        [[  7,  13,  13],
#         [  9,  15,  15],
#         [ 14,  20,  20],
#         ...,
#         [103,  64,  47],
#         [105,  66,  49],
#         [107,  68,  51]],
#
#        [[  6,  12,  12],
#         [  9,  15,  15],
#         [ 13,  19,  19],
#         ...,
#         [ 97,  58,  41],
#         [ 99,  60,  43],
#         [101,  62,  45]],
#
#        [[  6,  12,  12],
#         [  9,  15,  15],
#         [ 13,  19,  19],
#         ...,
#         [ 93,  54,  37],
#         [ 95,  56,  39],
#         [ 97,  58,  41]]], dtype=uint8)

# %%
plt.imshow(full)

# %%
cv2.findCirclesGrid
